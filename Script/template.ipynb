# %% [markdown]
# # Template

# %% [markdown]
# This notebook just contains the common dependencies between experiments and the base custom palette for the visualizations.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

BASE_CUSTOM_PALETTE = {
    1 :"#264653",
    2 : "#287271",
    4 : "#2a9d8f",
    8 : "#e9c46a",
    16 : "#f4a261",
    32 : "#ee8959",
    64 : "#e76f51"
}

# custom palette taken here : https://coolors.co/palette/264653-287271-2a9d8f-e9c46a-f4a261-ee8959-e76f51
